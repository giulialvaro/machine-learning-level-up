# %% [markdown]
# # 🌈 Clase 04 - Análisis Exploratorio

# %% [markdown]
# Importar galerías, cread df, primeras observaciones

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/winequality-red.csv', sep = ",")
df
# Out:
#       fixed acidity   volatile acidity   citric acid    residual sugar   \
# 0               7.4                0.70          -                  1.9
# 1               7.8                0.88          -                  2.6
# 2               7.8                0.76          0.04               2.3
# 3              11.2                0.28          0.56               1.9
# 4               7.4                0.70          -                  1.9
# ...             ...                 ...           ...               ...
# 1594            6.2                0.60          0.08               2.0
# 1595            5.9                0.55           0.1               2.2
# 1596            6.3                0.51          0.13               2.3
# 1597            5.9              645.00          0.12               2.0
# 1598            6.0                0.31          0.47               3.6
#
#       chlorides  free sulfur dioxide   total sulfur dioxide    density    pH  \
# ...

# %%
df.head(10)
# Out:
#    fixed acidity   volatile acidity   citric acid    residual sugar   \
# 0            7.4                0.70          -                  1.9
# 1            7.8                0.88          -                  2.6
# 2            7.8                0.76          0.04               2.3
# 3           11.2                0.28          0.56               1.9
# 4            7.4                0.70          -                  1.9
# 5            7.4                0.66          -                  1.8
# 6            7.9                0.60          0.06               1.6
# 7            7.3                0.65          -                  1.2
# 8            7.8                0.58          0.02               2.0
# 9            7.5                0.50          0.36               6.1
#
#    chlorides  free sulfur dioxide   total sulfur dioxide   density    pH  \
# 0      0.076                 11.0                      34  0.99780  3.51
# ...

# %%
df.tail()
# Out:
#       fixed acidity   volatile acidity   citric acid    residual sugar   \
# 1594            6.2                0.60          0.08               2.0
# 1595            5.9                0.55           0.1               2.2
# 1596            6.3                0.51          0.13               2.3
# 1597            5.9              645.00          0.12               2.0
# 1598            6.0                0.31          0.47               3.6
#
#       chlorides  free sulfur dioxide   total sulfur dioxide    density    pH  \
# 1594      0.090                 32.0                      44  0.099490  3.45
# 1595      0.062                 39.0                      51  0.099512  3.52
# 1596      0.076                 29.0                      40  0.099574  3.42
# 1597      0.075                 32.0                      44  0.099547  3.57
# 1598      0.067                 18.0                      42  0.099549  3.39
#
#       sulphates alcohol  quality
# 1594       0.58    10.5        5
# ...

# %%
# Dimensiones del df
print(df.shape)
# Out:
# (1599, 12)

# %%
# Validar q es un df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Columnas
df.columns
# Out:
# Index(['fixed acidity', ' volatile acidity ', ' citric acid ',
#        ' residual sugar ', 'chlorides', 'free sulfur dioxide',
#        ' total sulfur dioxide ', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df.dtypes
# Out:
# fixed acidity             float64
#  volatile acidity         float64
#  citric acid               object
#  residual sugar           float64
# chlorides                 float64
# free sulfur dioxide       float64
#  total sulfur dioxide       int64
# density                   float64
# pH                        float64
# sulphates                 float64
# alcohol                    object
# quality                     int64
# dtype: object

# %% [markdown]
# # Transformaciones dataset (extra)

# %%
df[' citric acid '] = pd.to_numeric(df[' citric acid '], errors='coerce')
df['alcohol'] = pd.to_numeric(df['alcohol'], errors='coerce')

# %%
df[' citric acid '] = df[' citric acid '].astype(float)
df['alcohol'] = df['alcohol'].astype(float)
df[' total sulfur dioxide '] = df[' total sulfur dioxide '].astype(float)

# %%
df.dtypes
# Out:
# fixed acidity             float64
#  volatile acidity         float64
#  citric acid              float64
#  residual sugar           float64
# chlorides                 float64
# free sulfur dioxide       float64
#  total sulfur dioxide     float64
# density                   float64
# pH                        float64
# sulphates                 float64
# alcohol                   float64
# quality                     int64
# dtype: object

# %%
df
# Out:
#       fixed acidity   volatile acidity    citric acid    residual sugar   \
# 0               7.4                0.70            NaN               1.9
# 1               7.8                0.88            NaN               2.6
# 2               7.8                0.76           0.04               2.3
# 3              11.2                0.28           0.56               1.9
# 4               7.4                0.70            NaN               1.9
# ...             ...                 ...            ...               ...
# 1594            6.2                0.60           0.08               2.0
# 1595            5.9                0.55           0.10               2.2
# 1596            6.3                0.51           0.13               2.3
# 1597            5.9              645.00           0.12               2.0
# 1598            6.0                0.31           0.47               3.6
#
#       chlorides  free sulfur dioxide   total sulfur dioxide    density    pH  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fixed acidity           1599 non-null   float64
#  1    volatile acidity       1599 non-null   float64
#  2    citric acid            1467 non-null   float64
#  3    residual sugar         1599 non-null   float64
#  4   chlorides               1599 non-null   float64
#  5   free sulfur dioxide     1599 non-null   float64
#  6    total sulfur dioxide   1599 non-null   float64
#  7   density                 1599 non-null   float64
#  8   pH                      1599 non-null   float64
#  9   sulphates               1599 non-null   float64
#  10  alcohol                 1593 non-null   float64
#  11  quality                 1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
nuevos_nombres = {
    'fixed acidity': 'fixed_acidity',
    ' volatile acidity ': 'volatile_acidity',
    ' citric acid ': 'citric_acid',
    ' residual sugar ': 'residual_sugar',
    'chlorides': 'chlorides',
    'free sulfur dioxide': 'free_sulfur_dioxide',
    ' total sulfur dioxide ': 'total_sulfur_dioxide',
    'density': 'density',
    'pH': 'pH',
    'sulphates': 'sulphates',
    ' alcohol ': 'alcohol',
    'quality': 'quality'
}

# Cambiar los nombres de las columnas
df.rename(columns=nuevos_nombres, inplace=True)

# Imprimir los nuevos nombres de las columnas
print("Nuevos nombres de columnas:")
print(df.columns)
# Out:
# Nuevos nombres de columnas:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1467 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1593 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Valores missing
df.count() #comparo con Non-null de df.info()
# Out:
# fixed_acidity           1599
# volatile_acidity        1599
# citric_acid             1467
# residual_sugar          1599
# chlorides               1599
# free_sulfur_dioxide     1599
# total_sulfur_dioxide    1599
# density                 1599
# pH                      1599
# sulphates               1599
# alcohol                 1593
# quality                 1599
# dtype: int64

# %% [markdown]
# # Estadística descriptiva

# %%
#Estadística descriptiva
df.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1467.000000     1599.000000
# mean        8.319637         81.478684     0.295358        2.538806
# std         1.741096        227.799577     0.184819        1.409928
# min         4.600000          0.120000     0.010000        0.900000
# 25%         7.100000          0.400000     0.140000        1.900000
# 50%         7.900000          0.520000     0.280000        2.200000
# 75%         9.200000          0.660000     0.440000        2.600000
# max        15.900000        975.000000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.066744            15.874922             47.340213     0.095735
# std       0.024535            10.460157             41.766193     0.029761
# ...

# %%
df.describe().round() #redondea los rdos
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count         1599.0            1599.0       1467.0          1599.0
# mean             8.0              81.0          0.0             3.0
# std              2.0             228.0          0.0             1.0
# min              5.0               0.0          0.0             1.0
# 25%              7.0               0.0          0.0             2.0
# 50%              8.0               1.0          0.0             2.0
# 75%              9.0               1.0          0.0             3.0
# max             16.0             975.0          1.0            16.0
#
#        chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density      pH  \
# count     1599.0               1599.0                1599.0   1599.0  1599.0
# mean         0.0                 16.0                  47.0      0.0     3.0
# std          0.0                 10.0                  42.0      0.0     0.0
# ...

# %% [markdown]
# # Visualizaciones

# %%
# Ver en W3 tutorias (Seaborn, Matplotlib, datavizcatalogue)
sns.kdeplot(df.quality, bw_adjust = 1)
# Out:
# <Axes: xlabel='quality', ylabel='Density'>

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# Podemos usar codigo para ver +1 variable a la vez
variables = ['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
       'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']

columns = 4

fig, axes = plt.subplots(len(variables) // columns, columns, figsize=(15,8))

for current_idx, variable in enumerate(variables):
    i = current_idx // columns
    j = current_idx % columns
    sns.kdeplot(df[variable], ax=axes[i][j])
    axes[i][j].set_title(variable)
    axes[i][j].set_xlabel('')

plt.tight_layout()
plt.show()

# %%
# Boxplots
variables = ['fixed_acidity', 'residual_sugar', 'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'sulphates', 'alcohol']

fig, axes = plt.subplots(1, len(variables), figsize=(15,6))

for ax, variable in zip(axes, variables):
    ax = sns.boxplot(y=variable, data=df, ax=ax)
plt.tight_layout()
plt.show()

# %%
# Scatterplot
from seaborn import lmplot
lmplot(x='free_sulfur_dioxide', y='total_sulfur_dioxide', data=df, fit_reg = True)

# %%
# Correlaciones
correlation = df.corr(method='pearson')
correlation.head()
# Out:
#                   fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity          1.000000         -0.067844     0.659544
# volatile_acidity      -0.067844          1.000000    -0.177697
# citric_acid            0.659544         -0.177697     1.000000
# residual_sugar         0.114777          0.026036     0.130642
# chlorides              0.019744         -0.016521    -0.097177
#
#                   residual_sugar  chlorides  free_sulfur_dioxide  \
# fixed_acidity           0.114777   0.019744            -0.153794
# volatile_acidity        0.026036  -0.016521            -0.055103
# citric_acid             0.130642  -0.097177            -0.078085
# residual_sugar          1.000000  -0.068035             0.187049
# chlorides              -0.068035   1.000000             0.015672
#
#                   total_sulfur_dioxide   density        pH  sulphates  \
# fixed_acidity                -0.109786 -0.300064 -0.682978   0.183006
# ...

# %%
# Heatmap
plt.figure(figsize=(10,10)) #tamaño del gráfico

# genero el graph
sns.heatmap(correlation,
            cbar = True,
            square = True,
            fmt = '.2f',
            annot = True,
            annot_kws = {'size':15},
            cmap = 'coolwarm')

# roto los ejes para q queden inclinados
plt.xticks(rotation=45)
plt.yticks(rotation=45)

plt.show()
