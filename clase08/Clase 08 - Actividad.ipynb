# %% [markdown]
# # Actividad de Clase 🌻

# %%
data = {
    'Tamaño': [1500, 1600, 1700, 1800, 1900],
    'Habitaciones': [3, 3, 3, 4, 4],
    'Edad': [10, 15, 20, 25, 30],
    'Precio': [300000, 320000, 340000, 360000, 380000]
}

# %% [markdown]
# 1. Librerias y dataframe

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.DataFrame(data)
df
# Out:
#    Tamaño  Habitaciones  Edad  Precio
# 0    1500             3    10  300000
# 1    1600             3    15  320000
# 2    1700             3    20  340000
# 3    1800             4    25  360000
# 4    1900             4    30  380000

# %% [markdown]
# 2. Graficamos la relacion de cada var con el precio

# %%
df.plot(x = "Tamaño", y = "Precio", style = "o", color = "purple")
plt.title("Tamaño vs Precio")
plt.xlabel("Tamaño en m2")
plt.ylabel("Precio de la propiedad")
plt.show()

# %%
df.plot(x = "Habitaciones", y = "Precio", style = "o", color = "purple")
plt.title("Habitaciones vs Precio")
plt.xlabel("Cantidad de habitaciones")
plt.ylabel("Precio de la propiedad")
plt.show()

# %%
df.plot(x = "Edad", y = "Precio", style = "o", color = "purple")
plt.title("Antiguedad vs Precio")
plt.xlabel("Antiguedad de la propiedad")
plt.ylabel("Precio de la propiedad")
plt.show()

# %% [markdown]
# 3. Divido en entrenamiento y prueba

# %%
# variable indep y vars dep
x = df[["Tamaño", "Habitaciones", "Edad"]]
y = df["Precio"]

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.6, random_state=42)

# %% [markdown]
# 4. Crear y entrenar el modelo

# %%
# Creo el modelo
modelo = LinearRegression()

# Entreno el modelo
modelo.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# 5. Hacer predicciones y evaluar el modelo

# %%
# Predicciones con el conjunto de prueba
y_pred = modelo.predict(X_test)
print(y_pred)

# Evaluación del modelo
MSE = mean_squared_error(y_test, y_pred)
R2 = r2_score(y_test, y_pred)

print(f"Error cuadrático medio: {MSE}")
print(f"Coeficiente de determinación: {R2}")
# Out:
# [319999.7783344  379999.7783344  339999.55666881]
# Error cuadrático medio: 0.09827127226147286
# Coeficiente de determinación: 0.999999999842064

# %% [markdown]
# 6. Visualizar resultados

# %%
# Graficar la relación entre cada característica y el precio
plt.figure(figsize=(12, 4))

plt.subplot(1, 3, 1)
plt.scatter(df['Tamaño'], df['Precio'], color='purple')
plt.plot(df['Tamaño'], modelo.predict(df[['Tamaño', 'Habitaciones', 'Edad']]), color='pink')
plt.xlabel('Tamaño')
plt.ylabel('Precio')
plt.title('Tamaño vs Precio')

plt.subplot(1, 3, 2)
plt.scatter(df['Habitaciones'], df['Precio'], color='lightgreen')
plt.plot(df['Habitaciones'], modelo.predict(df[['Tamaño', 'Habitaciones', 'Edad']]), color='pink')
plt.xlabel('Habitaciones')
plt.ylabel('Precio')
plt.title('Habitaciones vs Precio')

plt.subplot(1, 3, 3)
plt.scatter(df['Edad'], df['Precio'], color='yellow')
plt.plot(df['Edad'], modelo.predict(df[['Tamaño', 'Habitaciones', 'Edad']]), color='pink')
plt.xlabel('Edad')
plt.ylabel('Precio')
plt.title('Edad vs Precio')

plt.tight_layout()
plt.show()
